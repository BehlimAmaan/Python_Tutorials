# %%
with open('example.txt', 'r') as file:
    content = file.read()
    print(content)
# Out:
# Sure! Here’s a paragraph for you:
#
# Learning is a continuous journey that goes beyond classrooms and textbooks.
# Every experience, whether big or small, teaches us something valuable about the world and ourselves.
# By staying curious, asking questions, and embracing challenges, we grow not only in knowledge but also in character.
# Consistent effort, patience, and a positive mindset can transform obstacles into opportunities, helping us achieve our goals and unlock our full potential.
# Life becomes more meaningful when we approach it with a willingness to learn and improve every day.
#
# If you want, I can also make it **shorter, more casual, or more professional** depending on your need. Which style do you prefer?

# %%
def cont_line_word_char(file_path):
    with open(file_path, 'r') as file:
       lines= file.readline()
       line_count = len(lines)
       word_count = sum(len(line.split()) for line in lines)
       char_count = sum(len(line) for line in lines)
       return line_count, word_count, char_count
   
file_path = 'example.txt'
lines, word, char = cont_line_word_char(file_path)
print(f"No. of Lines : {lines}\n No. of Words : {word}\n No. of Character : {char}")
# Out:
# No. of Lines : 34
#  No. of Words : 28
#  No. of Character : 34

# %%
lines = ["Hi Amaan", "How are you?", "This is a new file."]

with open("destination.txt", "w") as file:
    for line in lines:
        file.write(line + "\n")
# Out:
# No. of Lines : 6
#  No. of Words : 5
#  No. of Character : 6
